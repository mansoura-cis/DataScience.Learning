# %% [markdown]
# # Lecture 1 Contripution
# - Types of Attributes
# - Statistical Tendency of Data
#     - Measuring Central Tendency
#         - Mean
#         - Median
#         - Mode
#     - Measuring the Dispersion of Data
#         - varience
#         - standard diviation
#         - range
#     - Basic Graphs
#         - BoxPlot
#         - Histogram

# %%
# 2 types of Attributes {'Categorical' : 'qualitative' , 'Numerical' : 'quantitative'}
Categorical = ['Nominal' , 'Binary' , 'Ordinal']
Numerical = ['Interval-Based' , 'Ratio-Based']

# the sets of data that can't be orderd
Nominal = [['Red' , 'Blue' , 'Green'], ['Doctor' , 'Nurse' , 'Engineer' , 'Farmer']]
# the sets of data have 2 values in each set
Binary =['Male' , 'Female']
# the sets of data that can be noramly ordered
Ordinal =[['Failed','Accepted' , 'Good' , 'VeryGood' , 'Excellent'] , ['Junior','Senior', 'Master', 'Leader', 'PM', 'CIO']]

Interval_temprature = range(-100,6000) # doesn't have true zero-based value 0C doesn't mean no temp
Ratio_Age = range(0,150)

for x in Ratio_Age:
    print(f'The Human have {x} is grow 1 year')

# %%
import numpy as np
import pandas as pd
from scipy import stats as st

# %%
set =[55,78,45,5,7,78,45,69,32,47,56,75,68,23]

print(np.mean(set))

print(sum(set)/len(set))
# Out:
# 48.785714285714285
# 48.785714285714285

# %%
print(np.median(set))
# Out:
# 51.0

# %%
print(st.mode(set)[0])
# Out:
# [45]

# %%
np.random.seed(1234)
df = pd.DataFrame(np.random.randn(10, 4),
                  columns=['Col1', 'Col2', 'Col3', 'Col4'])
boxplot = df.boxplot(column=['Col1', 'Col2', 'Col3'])
boxplot

# %%
df = pd.DataFrame(
    np.random.randint(2, 8, 5000),
    columns = ['one'])
df['two'] = df['one'] + np.random.randint(2, 8, 5000)
ax = df.plot.hist(bins=12, alpha=0.5)

# %%
arr =np.random.randint(2, 8, 5000)
for x in arr:
    print(x)
# Out:
# 7
# 3
# 5
# 3
# 5
# 3
# 2
# 4
# 7
# 7
# 2
# 7
# 4
# 3
# 5
# 3
# 7
# 5
# 6
# 3
# 7
# 4
# 4
# 3
# 6
# 3
# 4
# 4
# 6
# 5
# 7
# 5
# 6
# 4
# 6
# 2
# 6
# 6
# 2
# 4
# 7
# 7
# 7
# 5
# 6
# 6
# 7
# 7
# 6
# 5
# 2
# 7
# 7
# 2
# 7
# 5
# 4
# 4
# 6
# 6
# 2
# 5
# 7
# 6
# 3
# 6
# 3
# 5
# 6
# 4
# 5
# 7
# 3
# 2
# 2
# 2
# 2
# 4
# 2
# 6
# 6
# 6
# 3
# 3
# 7
# 5
# 4
# 2
# 5
# 2
# 7
# 2
# 3
# 7
# 7
# 2
# 4
# 4
# 5
# 6
# 6
# 3
# 4
# 5
# 6
# 4
# 2
# 6
# 4
# 4
# 7
# 7
# 6
# 4
# 2
# 7
# 5
# 6
# 6
# 7
# 4
# 6
# 5
# 7
# 7
# 7
# 4
# 2
# 2
# 7
# 5
# 6
# 4
# 4
# 3
# 5
# 5
# 2
# 7
# 5
# 5
# 2
# 2
# 7
# 6
# 3
# 3
# 2
# 2
# 6
# 7
# 3
# 2
# 7
# 2
# 3
# 7
# 7
# 3
# 7
# 6
# 6
# 7
# 4
# 4
# 5
# 6
# 4
# 3
# 3
# 4
# 5
# 5
# 7
# 2
# 5
# 3
# 2
# 3
# 7
# 5
# 6
# 7
# 3
# 7
# 4
# 7
# 6
# 3
# 3
# 3
# 6
# 2
# 6
# 6
# 3
# 5
# 3
# 6
# 5
# 7
# 3
# 4
# 4
# 5
# 6
# 2
# 3
# 6
# 5
# 5
# 3
# 6
# 5
# 3
# 3
# 2
# 6
# 5
# 4
# 7
# 5
# 2
# 3
# 3
# 5
# 5
# 3
# 3
# 3
# 7
# 7
# 5
# 5
# 4
# 3
# 5
# 3
# 3
# 2
# 7
# 4
# 4
# 2
# 5
# 3
# 5
# 3
# 7
# 6
# ...
